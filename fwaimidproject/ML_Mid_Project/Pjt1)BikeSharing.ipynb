# %% [markdown]
# # Machine Learning Work Flow, Pipe Line
#
# **주의사항**
# * preview)를 보고 할 것.
# * 시각화에 날짜 붙이는 것에 너무 집착하지 말자.
#     * 판다스를 경유하면 편하다.

# %% [markdown]
# # Training Work Flow
#
# **무엇을 무슨 순서로 했는가?**
# 1. 여기에
# 2. 채워서
# 3. 적으면
# 4. 됩니다.

# %% [markdown]
# ## 01. Data Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = 'https://raw.githubusercontent.com/RayleighKim/Example_datasets/master/Bike-Sharing-Dataset/hour.csv'
rides = pd.read_csv(data_path)

# %%
rides.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0  ...        0.0       3          13   16
# 1        2  2011-01-01       1   0  ...        0.0       8          32   40
# 2        3  2011-01-01       1   0  ...        0.0       5          27   32
# 3        4  2011-01-01       1   0  ...        0.0       3          10   13
# 4        5  2011-01-01       1   0  ...        0.0       0           1    1
#
# [5 rows x 17 columns]

# %%
type(rides)
# Out:
# pandas.core.frame.DataFrame

# %%
rides[:24*14].plot(x='dteday', y='cnt')

# %% [markdown]
# ## 02. Train/Validation/Test Split
# **실습**
# 1. 데이터를 분리 하시오.
#     * 마지막 21일은 test_data로 분리
#     * 그 다음 60일(-81 ~ -21)은 val_data로 분리
#     * 나머지는 train_data로 분리
#
# **주의사항**
# * 이걸 제일 먼저 해야 한다.
# * Training phase에서는
#     1. 모든 탐색, 전처리규칙제작 등은 training set에서.
#     2. validation셋에 대하여 고민해보자.

# %%
test_data = rides[-21*24:]
val_data = rides[-81*24:-21*24]
train_data = rides[:-81*24]

# %%
train_data
# Out:
#        instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0            1  2011-01-01       1   0  ...     0.0000       3          13   16
# 1            2  2011-01-01       1   0  ...     0.0000       8          32   40
# 2            3  2011-01-01       1   0  ...     0.0000       5          27   32
# 3            4  2011-01-01       1   0  ...     0.0000       3          10   13
# 4            5  2011-01-01       1   0  ...     0.0000       0           1    1
# ...        ...         ...     ...  ..  ...        ...     ...         ...  ...
# 15430    15431  2012-10-10       4   1  ...     0.0000       0           6    6
# 15431    15432  2012-10-10       4   1  ...     0.1045       0           6    6
# 15432    15433  2012-10-10       4   1  ...     0.0896       2          38   40
# 15433    15434  2012-10-10       4   1  ...     0.0896       3         172  175
# 15434    15435  2012-10-10       4   1  ...     0.1045       9         498  507
#
# [15435 rows x 17 columns]

# %% [markdown]
# ## 03. EDA for Feature Engineering
#
# * EDA는 명확한 목적하에, 반드시 workflow에 도움이 되는 결과를 도출해야 함.
# * EDA를 검색해봐도 좋음.

# %%
train_data.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0  ...        0.0       3          13   16
# 1        2  2011-01-01       1   0  ...        0.0       8          32   40
# 2        3  2011-01-01       1   0  ...        0.0       5          27   32
# 3        4  2011-01-01       1   0  ...        0.0       3          10   13
# 4        5  2011-01-01       1   0  ...        0.0       0           1    1
#
# [5 rows x 17 columns]

# %%
print('무엇이 보이는가?')
train_data[:24*10].plot(x='dteday', y='cnt', figsize=(13,8) )
# train_data[:24*10].plot(x='dteday', y=['registered','cnt'], figsize=(13,8) )
# Out:
# 무엇이 보이는가?

# %% [markdown]
# **EDA의 결론을 적으시오**<br>
# Hint : Feature Engineering/Extraction 계획을 하시오.<br>
# [궁금할지도 모르는 내용](https://datascience.stackexchange.com/questions/29006/feature-selection-vs-feature-extraction-which-to-use-when)

# %% [markdown]
# ## 04. Feature Engineering.
#
# **주의사항** : 여기에서 제작 한 것을, test셋에서도 사용하게 될 것이다. 마구잡이로 하면 안됨
#
# 1. any ideas : ?
# 1. dummy : ?
# 2. scaling : ?
# 3. drop : ?
# 4. impute : ?

# %%
# dummy & drop
dummy_fields = ['season', 'weathersit', 'mnth', 'hr', 'weekday']

train_data = pd.get_dummies(train_data, columns=dummy_fields)
val_data = pd.get_dummies(val_data, columns=dummy_fields)
test_data = pd.get_dummies(test_data, columns=dummy_fields)

fields_to_drop = ['instant', 'dteday']

train_data.drop(fields_to_drop, axis=1, inplace=True)
val_data.drop(fields_to_drop, axis=1, inplace=True)
test_data.drop(fields_to_drop, axis=1, inplace=True)

# %%
train_col = set(train_data.columns)
val_col = set(val_data.columns)
test_col = set(test_data.columns)

for feature in (train_col - val_col) :
    val_data[feature] = 0

for feature in (train_col - test_col) :
    test_data[feature] = 0

# %%
val_data = val_data[train_data.columns]
test_data = test_data[train_data.columns]

# %%
# scaling
quant_features = ['temp', 'atemp', 'hum', 'windspeed']

means = train_data[quant_features].mean()
stds = train_data[quant_features].std()

train_data[quant_features] = (train_data[quant_features] - means) / stds
val_data[quant_features] = (val_data[quant_features] - means) / stds
test_data[quant_features] = (test_data[quant_features] - means) / stds

# %%
targets = ['casual', 'registered', 'cnt']

x_train, y_train = train_data.drop(targets, axis=1), train_data['cnt']
x_val, y_val = val_data.drop(targets, axis=1), val_data['cnt']
x_test, y_test = test_data.drop(targets, axis=1), test_data['cnt']

# %% [markdown]
# Feature Engineering 파트에서 사용한 것들을 diagram으로 잘 그려두기.

# %% [markdown]
# ## 05. Modeling & Hyperparameter tuning
#
# * Validation set을 적극 활용해보자.
# * 여러 모델 다 사용해봐도 좋음.

# %%
from sklearn.neural_network import MLPRegressor

# %%
ann = MLPRegressor(hidden_layer_sizes=(64, 32), early_stopping=True,max_iter=2000, verbose=True)
ann.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 32230.02547366
# Validation score: -0.773289
# Iteration 2, loss = 22374.39077517
# Validation score: 0.157040
# Iteration 3, loss = 10797.72623401
# Validation score: 0.416620
# Iteration 4, loss = 8802.29140307
# Validation score: 0.492617
# Iteration 5, loss = 7695.38440023
# Validation score: 0.556206
# Iteration 6, loss = 6718.41565504
# Validation score: 0.612812
# Iteration 7, loss = 5849.76674245
# Validation score: 0.661806
# Iteration 8, loss = 5142.88959450
# Validation score: 0.700080
# Iteration 9, loss = 4632.72006541
# Validation score: 0.726522
# Iteration 10, loss = 4280.97715128
# Validation score: 0.746776
# Iteration 11, loss = 4015.10730946
# Validation score: 0.760976
# Iteration 12, loss = 3794.18340034
# Validation score: 0.774723
# Iteration 13, loss = 3596.92367400
# Validation score: 0.788033
# Iteration 14, loss = 3417.16461410
# Validation score: 0.798953
# Iteration 15, loss = 3237.67876881
# Validation score: 0.809996
# Iteration 16, loss = 3064.14379095
# Validation score: 0.820277
# Iteration 17, loss = 2894.35937300
# Validation score: 0.830326
# Iteration 18, loss = 2728.81762896
# Validation score: 0.840325
# Iteration 19, loss = 2575.32889444
# Validation score: 0.848994
# Iteration 20, loss = 2426.45938269
# Validation score: 0.858135
# Iteration 21, loss = 2284.02797674
# Validation score: 0.865998
# Iteration 22, loss = 2158.73285060
# Validation score: 0.873195
# Iteration 23, loss = 2036.92380019
# Validation score: 0.879702
# Iteration 24, loss = 1925.65579194
# Validation score: 0.885935
# Iteration 25, loss = 1824.25823940
# Validation score: 0.891401
# Iteration 26, loss = 1734.14049707
# Validation score: 0.896127
# Iteration 27, loss = 1654.35403123
# Validation score: 0.901096
# Iteration 28, loss = 1577.48569209
# Validation score: 0.905195
# Iteration 29, loss = 1510.76742981
# Validation score: 0.908834
# Iteration 30, loss = 1449.01103082
# Validation score: 0.911437
# Iteration 31, loss = 1396.82126308
# Validation score: 0.914989
# Iteration 32, loss = 1345.15678148
# Validation score: 0.917694
# Iteration 33, loss = 1299.98226373
# Validation score: 0.920017
# Iteration 34, loss = 1261.88869056
# Validation score: 0.921353
# Iteration 35, loss = 1224.33295473
# Validation score: 0.923674
# Iteration 36, loss = 1195.26848360
# Validation score: 0.925837
# Iteration 37, loss = 1162.02147590
# Validation score: 0.927237
# Iteration 38, loss = 1132.49678469
# Validation score: 0.928759
# Iteration 39, loss = 1109.68823284
# Validation score: 0.930147
# Iteration 40, loss = 1084.76275165
# Validation score: 0.931645
# Iteration 41, loss = 1065.54098681
# Validation score: 0.932523
# Iteration 42, loss = 1046.52995556
# Validation score: 0.933679
# Iteration 43, loss = 1026.07507396
# Validation score: 0.934717
# Iteration 44, loss = 1009.62477871
# Validation score: 0.935627
# Iteration 45, loss = 991.51114804
# Validation score: 0.936160
# Iteration 46, loss = 977.63005076
# Validation score: 0.936838
# Iteration 47, loss = 962.89275881
# Validation score: 0.938160
# Iteration 48, loss = 951.82906262
# Validation score: 0.938459
# Iteration 49, loss = 936.63563220
# Validation score: 0.938584
# Iteration 50, loss = 925.05948240
# Validation score: 0.939688
# Iteration 51, loss = 913.60109531
# Validation score: 0.939943
# Iteration 52, loss = 904.92018298
# Validation score: 0.940841
# Iteration 53, loss = 895.50522181
# Validation score: 0.940971
# Iteration 54, loss = 882.36354728
# Validation score: 0.941297
# Iteration 55, loss = 873.95142721
# Validation score: 0.941359
# Iteration 56, loss = 861.55188368
# Validation score: 0.942619
# Iteration 57, loss = 855.61116377
# Validation score: 0.942473
# Iteration 58, loss = 845.74146639
# Validation score: 0.943100
# Iteration 59, loss = 836.14694039
# Validation score: 0.943433
# Iteration 60, loss = 828.95187978
# Validation score: 0.943950
# Iteration 61, loss = 819.68316433
# Validation score: 0.943945
# Iteration 62, loss = 812.38168387
# Validation score: 0.944711
# Iteration 63, loss = 806.22843259
# Validation score: 0.944957
# Iteration 64, loss = 801.66458986
# Validation score: 0.945082
# Iteration 65, loss = 793.69100629
# Validation score: 0.944916
# Iteration 66, loss = 785.01394236
# Validation score: 0.945762
# Iteration 67, loss = 780.08937372
# Validation score: 0.945582
# Iteration 68, loss = 773.87687626
# Validation score: 0.945750
# Iteration 69, loss = 770.89797387
# Validation score: 0.946105
# Iteration 70, loss = 762.05558193
# Validation score: 0.946599
# Iteration 71, loss = 756.53628952
# Validation score: 0.946858
# Iteration 72, loss = 752.60049309
# Validation score: 0.946834
# Iteration 73, loss = 746.33269595
# Validation score: 0.947141
# Iteration 74, loss = 743.48734206
# Validation score: 0.947620
# Iteration 75, loss = 739.33331063
# Validation score: 0.946820
# Iteration 76, loss = 734.19237030
# Validation score: 0.947545
# Iteration 77, loss = 730.02679349
# Validation score: 0.947763
# Iteration 78, loss = 723.22773957
# Validation score: 0.947454
# Iteration 79, loss = 726.79122660
# Validation score: 0.948002
# Iteration 80, loss = 715.76853269
# Validation score: 0.947731
# Iteration 81, loss = 716.11798075
# Validation score: 0.947069
# Iteration 82, loss = 711.92958987
# Validation score: 0.948424
# Iteration 83, loss = 709.59276911
# Validation score: 0.948287
# Iteration 84, loss = 703.62163830
# Validation score: 0.948579
# Iteration 85, loss = 700.03891406
# Validation score: 0.948233
# Iteration 86, loss = 694.82866622
# Validation score: 0.948735
# Iteration 87, loss = 694.31728794
# Validation score: 0.948821
# Iteration 88, loss = 691.78398274
# Validation score: 0.948879
# Iteration 89, loss = 691.06884504
# Validation score: 0.947757
# Iteration 90, loss = 691.68371307
# Validation score: 0.949164
# Iteration 91, loss = 684.19423191
# Validation score: 0.949227
# Iteration 92, loss = 684.06386205
# Validation score: 0.949282
# Iteration 93, loss = 679.45704249
# Validation score: 0.949442
# Iteration 94, loss = 679.87228264
# Validation score: 0.949841
# Iteration 95, loss = 673.33133056
# Validation score: 0.949488
# Iteration 96, loss = 670.18667231
# Validation score: 0.949515
# Iteration 97, loss = 667.02200985
# Validation score: 0.948877
# Iteration 98, loss = 666.48547751
# Validation score: 0.949860
# Iteration 99, loss = 658.64594688
# Validation score: 0.949844
# Iteration 100, loss = 658.93628647
# Validation score: 0.949761
# Iteration 101, loss = 656.15832215
# Validation score: 0.949737
# Iteration 102, loss = 656.77818193
# Validation score: 0.949475
# Iteration 103, loss = 650.83375633
# Validation score: 0.949734
# Iteration 104, loss = 649.75065543
# Validation score: 0.949807
# Iteration 105, loss = 644.14334407
# Validation score: 0.949760
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=True, epsilon=1e-08,
#              hidden_layer_sizes=(64, 32), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=2000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=True,
#              warm_start=False)

# %%
y_tr_p = ann.predict(x_train)
y_va_p = ann.predict(x_val)
y_te_p = ann.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as mse, r2_score

# %%
rmse_ann_tr = mse(y_train, y_tr_p)**(1/2)
rmse_ann_va = mse(y_val, y_va_p)**(1/2)

r2_ann_tr = r2_score(y_train, y_tr_p)
r2_ann_va = r2_score(y_val, y_va_p)

print('training // 뉴럴넷의 RMSE : {:.3f}, R^2: {:.5f}'.format(rmse_ann_tr, r2_ann_tr))
print('validation // 뉴럴넷의 RMSE : {:.3f}, R^2: {:.5f}'.format(rmse_ann_va, r2_ann_va))
# Out:
# training // 뉴럴넷의 RMSE : 36.438, R^2: 0.95857
# validation // 뉴럴넷의 RMSE : 71.622, R^2: 0.87916

# %% [markdown]
# ## 06. Evaluation on Test set & make a pipeline
#
# * Go? or Not to go?
# * 모든 규칙을 정리하여 파이프라인을 제작하자.

# %%
rmse_ann_te = mse(y_test, y_te_p)**(1/2)
r2_ann_te = r2_score(y_test, y_te_p)
print('test // 뉴럴넷의 RMSE : {:.3f}, R^2: {:.5f}'.format(rmse_ann_te, r2_ann_te))
# Out:
# test // 뉴럴넷의 RMSE : 70.273, R^2: 0.77352

# %% [markdown]
# # ML Pipeline for system
#
# Training Work Flow 의 모든 것을 재활용 한다.
# * 처음에 pipeline부터 먼저 그린다. 같이 그리자!
#
# **To-Do**
# 1. Training Phase : **전체 데이터를 이용하여 모델을 만든다.**(train/valid/test안나눈다.)
#     * 하지만 이 실습에서는, 주어진 데이터만을 이용해야 하기 때문에 마지막 21일을 new_data로 떼어둔다.
#     * 나머지 데이터를 old_data로 떼어둔다.
#     * new_data는 마치 진짜로 데이터가 새로 들어올 때 처럼 사용할 것이다.
#
# 3. Prediction Phase :
#     * new_data를 이용하여 예측값을 만들어본다.
# 4. Monitoring ?

# %% [markdown]
# ## 01. Training Phase for model serving
#
# * Training Work Flow의 여러 규칙들을, 전체 데이터(old_data)를 이용하여 다시 제작하면 됨.

# %%
data_path = 'https://raw.githubusercontent.com/RayleighKim/Example_datasets/master/Bike-Sharing-Dataset/hour.csv'
rides = pd.read_csv(data_path)

new_data = rides[-21*24:]
old_data = rides[:-21*24]

# %%
dummy_fields = ['season', 'weathersit', 'mnth', 'hr', 'weekday']
old_data = pd.get_dummies(old_data, columns=dummy_fields)

fields_to_drop = ['instant', 'dteday']
old_data.drop(fields_to_drop, axis=1, inplace=True)

# %%
quant_features = ['temp', 'atemp', 'hum', 'windspeed']

means = old_data[quant_features].mean()
stds = old_data[quant_features].std()

old_data[quant_features] = (old_data[quant_features] - means) / stds

# %%
targets=['casual', 'registered', 'cnt']

x_old, y_old = old_data.drop(targets, axis=1), old_data['cnt']

# %%
from sklearn.neural_network import MLPRegressor
ann = MLPRegressor(hidden_layer_sizes=(64, 32), early_stopping=True, max_iter=2000, verbose=True)
ann.fit(x_old, y_old)
# Out:
# Iteration 1, loss = 33352.11430612
# Validation score: -0.834356
# Iteration 2, loss = 22251.07382743
# Validation score: 0.179314
# Iteration 3, loss = 10861.48612226
# Validation score: 0.425155
# Iteration 4, loss = 8985.34651088
# Validation score: 0.497030
# Iteration 5, loss = 7760.26096958
# Validation score: 0.561318
# Iteration 6, loss = 6659.34282182
# Validation score: 0.618715
# Iteration 7, loss = 5745.43834048
# Validation score: 0.665270
# Iteration 8, loss = 5093.22443170
# Validation score: 0.697409
# Iteration 9, loss = 4681.10480807
# Validation score: 0.718506
# Iteration 10, loss = 4416.96859600
# Validation score: 0.733207
# Iteration 11, loss = 4224.31973381
# Validation score: 0.744783
# Iteration 12, loss = 4051.61930255
# Validation score: 0.756114
# Iteration 13, loss = 3886.72744696
# Validation score: 0.766354
# Iteration 14, loss = 3736.45041521
# Validation score: 0.776411
# Iteration 15, loss = 3579.76037795
# Validation score: 0.785792
# Iteration 16, loss = 3419.23096882
# Validation score: 0.796759
# Iteration 17, loss = 3249.89634916
# Validation score: 0.806476
# Iteration 18, loss = 3087.86220690
# Validation score: 0.816211
# Iteration 19, loss = 2922.90590242
# Validation score: 0.825582
# Iteration 20, loss = 2768.89307567
# Validation score: 0.834559
# Iteration 21, loss = 2616.92606129
# Validation score: 0.843400
# Iteration 22, loss = 2476.19719271
# Validation score: 0.851393
# Iteration 23, loss = 2339.94530685
# Validation score: 0.859427
# Iteration 24, loss = 2206.72347400
# Validation score: 0.866771
# Iteration 25, loss = 2092.87892792
# Validation score: 0.873083
# Iteration 26, loss = 1979.85268963
# Validation score: 0.878937
# Iteration 27, loss = 1879.65977704
# Validation score: 0.885074
# Iteration 28, loss = 1782.04905565
# Validation score: 0.889454
# Iteration 29, loss = 1698.57847203
# Validation score: 0.894487
# Iteration 30, loss = 1622.94980634
# Validation score: 0.898340
# Iteration 31, loss = 1555.04844542
# Validation score: 0.902013
# Iteration 32, loss = 1497.95015318
# Validation score: 0.904730
# Iteration 33, loss = 1445.79433919
# Validation score: 0.907249
# Iteration 34, loss = 1394.53288245
# Validation score: 0.909552
# Iteration 35, loss = 1353.34560894
# Validation score: 0.912645
# Iteration 36, loss = 1315.79422365
# Validation score: 0.914088
# Iteration 37, loss = 1279.23311920
# Validation score: 0.916087
# Iteration 38, loss = 1245.89229508
# Validation score: 0.917581
# Iteration 39, loss = 1217.27708395
# Validation score: 0.919849
# Iteration 40, loss = 1191.78399753
# Validation score: 0.921019
# Iteration 41, loss = 1163.45282803
# Validation score: 0.922556
# Iteration 42, loss = 1142.09087540
# Validation score: 0.923890
# Iteration 43, loss = 1118.47474262
# Validation score: 0.925214
# Iteration 44, loss = 1098.47477996
# Validation score: 0.926616
# Iteration 45, loss = 1080.87157521
# Validation score: 0.927392
# Iteration 46, loss = 1062.15632432
# Validation score: 0.928003
# Iteration 47, loss = 1047.74324659
# Validation score: 0.929327
# Iteration 48, loss = 1029.72587845
# Validation score: 0.930293
# Iteration 49, loss = 1017.40845323
# Validation score: 0.930885
# Iteration 50, loss = 1003.00719653
# Validation score: 0.931224
# Iteration 51, loss = 991.03918791
# Validation score: 0.931669
# Iteration 52, loss = 979.99981281
# Validation score: 0.933247
# Iteration 53, loss = 969.63492421
# Validation score: 0.933463
# Iteration 54, loss = 960.92464859
# Validation score: 0.934458
# Iteration 55, loss = 949.27122604
# Validation score: 0.935042
# Iteration 56, loss = 941.67558281
# Validation score: 0.934669
# Iteration 57, loss = 933.37796088
# Validation score: 0.936218
# Iteration 58, loss = 922.47612056
# Validation score: 0.935845
# Iteration 59, loss = 916.07068953
# Validation score: 0.935563
# Iteration 60, loss = 909.49387352
# Validation score: 0.936803
# Iteration 61, loss = 901.84452148
# Validation score: 0.937859
# Iteration 62, loss = 899.76678840
# Validation score: 0.938096
# Iteration 63, loss = 889.83841141
# Validation score: 0.938414
# Iteration 64, loss = 881.23168502
# Validation score: 0.938585
# Iteration 65, loss = 874.00455551
# Validation score: 0.939483
# Iteration 66, loss = 867.61992042
# Validation score: 0.939839
# Iteration 67, loss = 864.80865154
# Validation score: 0.940385
# Iteration 68, loss = 857.01142378
# Validation score: 0.940277
# Iteration 69, loss = 852.04979174
# Validation score: 0.941094
# Iteration 70, loss = 848.18781886
# Validation score: 0.941076
# Iteration 71, loss = 841.59240135
# Validation score: 0.941236
# Iteration 72, loss = 834.54294736
# Validation score: 0.941464
# Iteration 73, loss = 829.90737904
# Validation score: 0.942091
# Iteration 74, loss = 826.80601888
# Validation score: 0.942172
# Iteration 75, loss = 819.12787351
# Validation score: 0.942709
# Iteration 76, loss = 816.03087849
# Validation score: 0.942884
# Iteration 77, loss = 809.59561599
# Validation score: 0.943096
# Iteration 78, loss = 807.11778196
# Validation score: 0.943272
# Iteration 79, loss = 804.83981804
# Validation score: 0.942815
# Iteration 80, loss = 798.34885248
# Validation score: 0.943506
# Iteration 81, loss = 794.75654225
# Validation score: 0.943293
# Iteration 82, loss = 792.75220156
# Validation score: 0.944319
# Iteration 83, loss = 787.41401290
# Validation score: 0.944521
# Iteration 84, loss = 781.86563727
# Validation score: 0.944828
# Iteration 85, loss = 781.10337430
# Validation score: 0.944802
# Iteration 86, loss = 774.25251948
# Validation score: 0.945073
# Iteration 87, loss = 773.53684220
# Validation score: 0.945198
# Iteration 88, loss = 768.67103781
# Validation score: 0.945514
# Iteration 89, loss = 767.36740201
# Validation score: 0.945336
# Iteration 90, loss = 763.10820060
# Validation score: 0.945797
# Iteration 91, loss = 759.99176372
# Validation score: 0.946122
# Iteration 92, loss = 758.54354318
# Validation score: 0.945721
# Iteration 93, loss = 753.74712437
# Validation score: 0.945949
# Iteration 94, loss = 750.99790304
# Validation score: 0.946497
# Iteration 95, loss = 746.91602122
# Validation score: 0.946442
# Iteration 96, loss = 745.68972181
# Validation score: 0.946670
# Iteration 97, loss = 740.62242798
# Validation score: 0.946651
# Iteration 98, loss = 740.41432401
# Validation score: 0.946706
# Iteration 99, loss = 737.47879417
# Validation score: 0.946970
# Iteration 100, loss = 737.10516054
# Validation score: 0.947372
# Iteration 101, loss = 732.37620110
# Validation score: 0.946865
# Iteration 102, loss = 728.85652037
# Validation score: 0.947119
# Iteration 103, loss = 725.17542559
# Validation score: 0.947964
# Iteration 104, loss = 723.93170155
# Validation score: 0.947532
# Iteration 105, loss = 721.82114888
# Validation score: 0.948025
# Iteration 106, loss = 717.98905802
# Validation score: 0.948239
# Iteration 107, loss = 715.53712695
# Validation score: 0.945747
# Iteration 108, loss = 716.52351301
# Validation score: 0.948110
# Iteration 109, loss = 711.94971745
# Validation score: 0.948605
# Iteration 110, loss = 712.46585861
# Validation score: 0.948614
# Iteration 111, loss = 705.78085507
# Validation score: 0.948364
# Iteration 112, loss = 703.25935699
# Validation score: 0.949223
# Iteration 113, loss = 702.34417293
# Validation score: 0.949295
# Iteration 114, loss = 701.02486486
# Validation score: 0.948971
# Iteration 115, loss = 697.63460158
# Validation score: 0.949620
# Iteration 116, loss = 694.70596072
# Validation score: 0.949918
# Iteration 117, loss = 692.04260294
# Validation score: 0.949665
# Iteration 118, loss = 692.74575759
# Validation score: 0.949682
# Iteration 119, loss = 690.10220094
# Validation score: 0.949900
# Iteration 120, loss = 688.57554937
# Validation score: 0.949654
# Iteration 121, loss = 687.38798514
# Validation score: 0.950164
# Iteration 122, loss = 683.80546188
# Validation score: 0.950309
# Iteration 123, loss = 682.27587592
# Validation score: 0.949998
# Iteration 124, loss = 680.86632888
# Validation score: 0.950252
# Iteration 125, loss = 678.29661617
# Validation score: 0.950249
# Iteration 126, loss = 679.51176014
# Validation score: 0.950331
# Iteration 127, loss = 674.12304084
# Validation score: 0.950345
# Iteration 128, loss = 672.66883911
# Validation score: 0.950882
# Iteration 129, loss = 671.38273062
# Validation score: 0.950917
# Iteration 130, loss = 667.51962152
# Validation score: 0.951095
# Iteration 131, loss = 666.80375580
# Validation score: 0.950494
# Iteration 132, loss = 666.54995814
# Validation score: 0.950494
# Iteration 133, loss = 666.68660883
# Validation score: 0.950806
# Iteration 134, loss = 660.67125662
# Validation score: 0.951347
# Iteration 135, loss = 659.77923609
# Validation score: 0.951013
# Iteration 136, loss = 657.98997897
# Validation score: 0.951400
# Iteration 137, loss = 655.36580352
# Validation score: 0.951403
# Iteration 138, loss = 654.59143169
# Validation score: 0.951141
# Iteration 139, loss = 652.62594431
# Validation score: 0.951554
# Iteration 140, loss = 653.25178874
# Validation score: 0.951812
# Iteration 141, loss = 650.17923564
# Validation score: 0.951631
# Iteration 142, loss = 648.25787569
# Validation score: 0.951547
# Iteration 143, loss = 645.37110766
# Validation score: 0.951495
# Iteration 144, loss = 647.99328857
# Validation score: 0.951224
# Iteration 145, loss = 646.07921400
# Validation score: 0.951891
# Iteration 146, loss = 643.94419285
# Validation score: 0.952198
# Iteration 147, loss = 643.37769455
# Validation score: 0.951415
# Iteration 148, loss = 641.02696522
# Validation score: 0.952315
# Iteration 149, loss = 637.58319078
# Validation score: 0.951748
# Iteration 150, loss = 635.70355424
# Validation score: 0.951998
# Iteration 151, loss = 633.76334072
# Validation score: 0.951388
# Iteration 152, loss = 634.22178365
# Validation score: 0.951872
# Iteration 153, loss = 631.75152968
# Validation score: 0.952265
# Iteration 154, loss = 631.86826322
# Validation score: 0.952205
# Iteration 155, loss = 628.18044206
# Validation score: 0.952407
# Iteration 156, loss = 627.11062971
# Validation score: 0.952166
# Iteration 157, loss = 623.23414401
# Validation score: 0.952144
# Iteration 158, loss = 625.35320347
# Validation score: 0.952340
# Iteration 159, loss = 622.74984229
# Validation score: 0.952483
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=True, epsilon=1e-08,
#              hidden_layer_sizes=(64, 32), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=2000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=True,
#              warm_start=False)

# %% [markdown]
# ## 02. Prediction Phase
#
# **아래 내용들을 이용하여 진행한다.**
# * 위 Training Phase에서 제작한 규칙
# * 위 Training Phase에서 제작한 모델

# %%
dummy_fields=['season', 'weathersit', 'mnth', 'hr', 'weekday']
new_data = pd.get_dummies(new_data, columns=dummy_fields)

fields_to_drop = ['instant', 'dteday']
new_data.drop(fields_to_drop, axis=1, inplace=True)

# %%
old_col = set(old_data.columns)
new_col = set(new_data.columns)

for feature in (old_col-new_col) :
    new_data[feature] = 0

old_data = old_data[old_data.columns]

# %%
new_data[quant_features] = (new_data[quant_features] - means) / stds

# %%
targets = ['casual', 'registered', 'cnt']

x_new, y_new = new_data.drop(targets, axis = 1), new_data['cnt']

# %%
y_new_p = ann.predict(x_new)

# %% [markdown]
# ## 03. Monitoring을 한다면?
# ** Discussion **

# %%
new_df = rides[-21*24:]
new_df['cnt_pred'] = y_new_p
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print('rmse:', mse(y_new, y_new_p)**(1/2))
new_df.plot(x='dteday', y=['cnt', 'cnt_pred'], figsize=(12, 8))
# Out:
# rmse: 196.0704429269675
